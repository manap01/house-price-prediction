# %%
# notebooks/01_data_exploration.ipynb (Jupyter Notebook Content)

{
  "cells": [
    ... (previous cells remain unchanged) ...
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# 04 - Evaluasi dan Visualisasi\n",
        "Analisis visual terhadap performa model dan distribusi error prediksi."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "# Plot hasil prediksi vs aktual\n",
        "plt.figure(figsize=(8,6))\n",
        "plt.scatter(y_test, y_pred_rf, alpha=0.5, label='Prediksi')\n",
        "plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2, label='Ideal')\n",
        "plt.xlabel('Harga Aktual')\n",
        "plt.ylabel('Harga Prediksi')\n",
        "plt.title('Prediksi vs Aktual - Random Forest')\n",
        "plt.legend()\n",
        "plt.grid(True)\n",
        "plt.show()"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "# Distribusi error\n",
        "errors = y_test - y_pred_rf\n",
        "plt.figure(figsize=(8,5))\n",
        "sns.histplot(errors, bins=30, kde=True)\n",
        "plt.title('Distribusi Error Random Forest')\n",
        "plt.xlabel('Error')\n",
        "plt.grid(True)\n",
        "plt.show()"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python",
      "version": "3.11"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
